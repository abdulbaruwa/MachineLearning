# %%
from bs4 import BeautifulSoup as soup
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import time
selfurl = "http://architectfinder.aia.org/frmSearch.aspx"
selfdriver = webdriver.PhantomJS()
selfdriver.set_window_size(1120, 550)

# %%
lta_url = 'https://www3.lta.org.uk/Competitions/Search/Search/#/?gen=/3&status=/4/5&grade=/1/2/3/4&page=0'
lta_base_url = 'https://www3.lta.org.uk/Competitions/Search/Search/#/?gen=/3&status=/4/5&grade=/1/2/3/4&page='

# %%
def replace_coma(value):
    return value.replace(',','')

# tournament_container = page_soup.findAll('div',{'class':'lta-competition-results'})
#tournamentDiv = res[0].findAll('div',{'class':'dh'})[0]
def getTournamentDetails(tournamentDiv):
    tournament = tournamentDiv.a.text
    tournamentCode = tournamentDiv.span.text
    tournamentLocationDiv = tournamentDiv.findAll('div',{'class':'di'})[0].text
    tournamentType = tournamentDiv.findAll('div',{'class':'dk'})[0].text
    tournamentDate  = tournamentDiv.findAll('div',{'class':'dl'})[0].text
    tournamentSex   = tournamentDiv.findAll('div',{'class':'dp'})[0].text
    tournamentGrade  = tournamentDiv.findAll('div',{'class':'d2'})[0].span.text
    tournamentDetailsLink =  'https://www3.lta.org.uk' + tournamentDiv.findAll('a',{'class':'titled'})[0]['href']
    
    tournamentRating  = tournamentDiv.findAll('div',{'class':'d2'})[0].div.text
    # print(tournamentDetailsLink)# + ' , ' + tournament + ',' + tournamentCode + ',' + tournamentType + ',' + tournamentDate + ',' + tournamentSex + ',' + tournamentGrade + ',' + tournamentRating)
    return replace_coma(tournamentDetailsLink) +  ' , ' + replace_coma(tournament) + ',' + replace_coma(tournamentCode) + ',' + replace_coma(tournamentType) + ',' + replace_coma(tournamentDate) + ',' + replace_coma(tournamentSex) + ',' + replace_coma(tournamentGrade) + ',' + replace_coma(tournamentRating) + '\n'

# %%
    
# page = 4
# def next_page(driver):
#     pagerNum = driver.find_element_by_id(str(page+1))
#     #x = selfdriver.find_element_by_id(str(page+1))
#     return pagerNum.get_attribute('class')=='normal active'
# url = lta_base_url + str(page)
# print(url)
# wait = WebDriverWait(selfdriver, 10)
# selfdriver.get(url)
# wait.until(next_page)
# # formloaded = wait.until(EC.element_to_be_clickable((By.CLASS_NAME, 'lta-input-select')))
# # x = selfdriver.find_element_by_id(str(page+1))
# # print(x.get_attribute('class')=='normal active')
# response = selfdriver.page_source
# body = soup(response, 'html.parser')
# tournament_containers = body.body.findAll('div',{'class':'dd'})
# itemsOnPage = len(tournament_containers)
# itemsOnPage

# %%
def get_url_body(url, driver, lmbda):
    wait = WebDriverWait(driver, 10)
    driver.get(url)
    try:
        wait.until(lmbda)
        return driver.page_source
    except Exception as e:
        print('next_page exception: ' + str(e))
        
def get_tournament_details(url, driver):
    driver.get(url)

# %%
filename = '/home/datadrive/lta_dump/tournaments.csv'
header = 'tournamentDetailsLink' +  ' , ' + 'tournament' + ',' + 'tournamentCode' + ',' + 'tournamentType' + ',' + 'tournamentDate' + ',' + 'tournamentSex' + ',' + 'tournamentGrade' + ',' + 'tournamentRating\n' 
f = open(filename, 'w')
f.write(header)
    
page = 0

def next_page(driver):
    pagerNum = driver.find_element_by_id(str(page+1))
    #x = selfdriver.find_element_by_id(str(page+1))
    return pagerNum.get_attribute('class')=='normal active'

itemsOnPage = 10
while (itemsOnPage > 0):
    url = lta_base_url + str(page)
    #print(url)

    response = get_url_body(url, selfdriver, next_page)
    
#     wait = WebDriverWait(selfdriver, 10)
#     selfdriver.get(url)
#     try:
#         wait.until(next_page)
#     except Exception as e:
#         print('next_page exception: ' + str(e))
        
#    response = selfdriver.page_source
    body = soup(response, 'html.parser')
    tournament_containers = body.body.findAll('div',{'class':'dd'})
    itemsOnPage = len(tournament_containers)
    print(itemsOnPage)
    page +=1
    time.sleep(1)
     
    for container in tournament_containers:
        file_line = getTournamentDetails(container)
        print(file_line)
        f.write(file_line)
    print('page ' + str(page) + ' done!')

#f.close()
# Out:
# 10
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D11ZNDV&evt=1-D120YZI , COMPETE Men's & Women's G4 Open Ranking Competition,AVO17W1385,Open,21 Oct to 22 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CSC4S3P&evt=1-CSC6AC5 , David Lloyd Basildon Indoor Autumn Tournament 2017,ESS17W0460,County Tour,21 Oct to 28 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-COBDDRH&evt=1-COBDFON , David Lloyd Hatfield Men's INDOOR FAST4 Event,HER17W0313,Open,21 Oct to 21 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D3U08OT&evt=1-D3U0SHC , Lee Valley Open Fast4,ESS17W2799,County Tour,21 Oct to 21 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CVB5IG9&evt=1-DFSKV9C , National Tennis Centre - Outdoors Winter Tournament,SUR17W0753,County Tour,21 Oct to 23 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CSMZJ15&evt=1-CSMZKJV , Sutton Tennis Academy Men's and Ladies INDOOR FAST4 Event,SUR17W0482,Open,21 Oct to 21 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CV05FEF&evt=1-CV060KC , West Bridgford Half Term Tournament,NOT17W0699,Regional Tour,21 Oct to 28 Oct,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CL8Y769&evt=1-CL90013 , DL Manchester North October Open 2017,LAN17W0232,Open,22 Oct to 28 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-COBEXUN&evt=1-COBF5I7 , David Lloyd Hatfield Men's INDOOR FAST4 ADULT PRIORITY Event,HER17W0314,Open,22 Oct to 22 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CRQ4JGN&evt=1-CRQ8N5X , Inspiring Community Tennis - Alcester Autumn Grade 4,WAR17W0453,County Tour,22 Oct to 25 Oct,Mens,4,Any - Any
#
# page 1 done!
# 10
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-DK8RGTU&evt=1-DK8UXZZ , Knighton Tennis Centre Indoor Veterans 40+ 50+ Grade 4,LEI17W4748,County Tour,22 Oct to 22 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CWHGG1X&evt=1-CWHGMRW , Lee Valley Men's Fast4 Event,ESS17W0896,County Tour,22 Oct to 22 Oct,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CZ5W1PR&evt=1-CZ5W5PS , Riverside Junior Open,BED17W1115,Regional Tour,22 Oct to 28 Oct,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTP308Z&evt=1-CTP67BZ , Sutton Tennis Academy Autumn Tournament#1,SUR17W0588,County Tour,22 Oct to 28 Oct,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-
Feb,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-COHRHYL&evt=1-COHRKY3 , David Lloyd Hatfield Men's INDOOR FAST4 Event,HER17W0348,Open,24 Feb to 24 Feb,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CW3MPMB&evt=1-CW3MNS8 , PREMIUM FAST4 Outdoors Tournament,SUR17W0863,County Tour,24 Feb to 24 Feb,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D17M3FV&evt=1-D17MH2G , South East County Tour Frindsbury LTC Mens Open Fast4 Grade 4,KEN17W1435,County Tour,24 Feb to 24 Feb,Mens,4,Any - Any
#
# page 17 done!
# 10
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTIAYRR&evt=1-CTIA3PZ , Sutton Tennis Academy Men's Open Indoor SuperSeries Tournament#7,SUR17W0581,Open,24 Feb to 04 Mar,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CX9O2E3&evt=1-CX9O424 , Tennis Solutions Masters Open At David Lloyd Bristol,AVO17W0995,Open,24 Feb to 25 Feb,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTH0DN3&evt=1-CTH0ET1 , Sutton Tennis Academy Men's INDOOR FAST4  Event,SUR17W0565,Open,25 Feb to 25 Feb,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D3ZYXZ9&evt=1-D4001KK , Cornwall County  Senior Indoor County Closed,COR17W2811,County Closed,03 Mar to 04 Mar,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CVDZXQH&evt=1-CVE0DYW , David Lloyd Enfield,MID17W0767,County Tour,03 Mar to 18 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CP1NPRT&evt=1-CP1N44N , David Lloyd Hatfield Men's INDOOR FAST4 Event,HER17W0350,Open,03 Mar to 03 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-DH68NCN&evt=1-DH68TSW , Senions FAST4 Outdoors Tournaments,SUR17W4571,County Tour,03 Mar to 04 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTHM2AZ&evt=1-CTHM2KZ , Sutton Tennis Academy Men's INDOOR FAST4 Event,SUR17W0566,Open,03 Mar to 03 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CP1RMBT&evt=1-CP1RLAV , David Lloyd Hatfield Men's INDOOR FAST4 Event,HER17W0351,Open,04 Mar to 04 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D3HYJUV&evt=1-D3HYV8C , Taunton  Grade 4 open and over  35's  indoor  Tournament,SOM17W2765,County Tour,04 Mar to 04 Mar,Mens,4,Any - Any
#
# page 18 done!
# 10
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CVNLT9R&evt=1-CVNLUWE , Bishops Park - Grade 4 - Weekend Series - MARCH,MID17W0814,Regional Tour,09 Mar to 11 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D0QXY79&evt=1-DDKLZU6 , COMPETE G3 Men's & Women's Open Competition,AVO17W1306,Open,10 Mar to 11 Mar,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CP1VCU1&evt=1-CP1VNOV , David Lloyd Hatfield Men's INDOOR FAST4 Event,HER17W0352,Open,10 Mar to 10 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTICMBN&evt=1-CTICK3D , Sutton Tennis Academy Men's Open Indoor SuperSeries Tournament#8,SUR17W0582,Open,10 Mar to 18 Mar,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTHPDDN&evt=1-CTHPNUL , Sutton Tennis Academy Men's and Ladies INDOOR FAST4 Event,SUR17W0568,Open,10 Mar to 10 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CP1YNWP&evt=1-CP1Z9AP , David Lloyd Hatfield Men's INDOOR FAST4 ADULT PRIORITY Event,HER17W0353,Open,11 Mar to 11 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTHQVWZ&evt=1-CTHQTVD , Sutton Tennis Academy Men's and Ladies INDOOR FAST4 ADULT PRIORITY Event,SUR17W0569,Open,11 Mar to 11 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D2100L5&evt=1-D210MIM , Stonehaven Grand Prix 2018,NSC17W1793,Open,16 Mar to 25 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D12GS3J&evt=1-D12HEUG , COMPETE Men's & Women's G4 Open Ranking Competition,AVO17W1390,Open,17 Mar to 18 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-DCOA3X7&evt=1-DCO9RBW , Open Grade 3 - Painswick LTC,GLO17W4231,Open,17 Mar to 17 Mar,Mens,3,Any - Any
#
# page 19 done!
# next_page exception: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Connection":"close","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:54590","User-Agent":"Python http auth"},"httpVersion":"1.1","method":"GET","url":"/attribute/class","urlParsed":{"anchor":"","query":"","file":"class","directory":"/attribute/","path":"/attribute/class","relative":"/attribute/class","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/attribute/class","queryKey":{},"chunks":["attribute","class"]},"urlOriginal":"/session/f9973ad0-ad31-11e7-bcb4-67b8e1c12a6f/element/:wdc:1507581584135/attribute/class"}}
# Screenshot: available via screen
#
# 10
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D42WR2R&evt=1-D42WX72 , Queens Mens County Tour,YOR17W2867,County Tour,17 Mar to 17 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTHT1O5&evt=1-CTHTW5D , Sutton Tennis Academy Men's INDOOR FAST4 Event,SUR17W0570,Open,17 Mar to 17 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CP24JN7&evt=1-CP24V1R , David Lloyd Hatfield Men's INDOOR FAST4 Event,HER17W0355,Open,18 Mar to 18 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CVKG2CJ&evt=1-CVKAMNU , PREMIUM FAST4 Open Tournament,SUR17W0804,County Tour,18 Mar to 18 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D7LCI1Z&evt=1-D7LCVF4 , Sherborne Boys School Grade 4 Adult Tournament,DOR17W3513,County Tour,18 Mar to 18 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CP27H9Z&evt=1-CP27S8F , David Lloyd Hatfield Men's INDOOR FAST4 ADULT PRIORITY Event,HER17W0356,Open,24 Mar to 24 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTHWZGL&evt=1-CTHX6EL , Sutton Tennis Academy Men's and Ladies INDOOR FAST4 Event,SUR17W0572,Open,24 Mar to 24 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CX9P7W9&evt=1-CX9P752 , Tennis Solutions Masters Open At David Lloyd Bristol,AVO17W0996,Open,24 Mar to 25 Mar,Mens,3,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CVVWDYT&evt=1-CVVWK5C , PREMIUM FAST4 Outdoors Tournament,SUR17W0827,County Tour,25 Mar to 25 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTHYDZH&evt=1-CTHYCJT , Sutton Tennis Academy Men's and Ladies INDOOR FAST4 Event,SUR17W0573,Open,25 Mar to 25 Mar,Mens,4,Any - Any
#
# page 20 done!
# 4
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-D3J400D&evt=1-D3J4PNG , Taunton open/Adults  grade 4,SOM17W2766,County Tour,25 Mar to 25 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CWI0A4L&evt=1-CWHZV8A , Carisbrooke Easter Grade 4,LEI17W0898,County Tour,26 Mar to 30 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CP2D979&evt=1-CP2D4CJ , David Lloyd Hatfield Men's INDOOR FAST4 Event,HER17W0358,Open,31 Mar to 31 Mar,Mens,4,Any - Any
#
# https://www3.lta.org.uk/Competitions/Event/?ctn=1-CTHZTPP&evt=1-CTHZUQ3 , Sutton Tennis Academy Men's and Ladies INDOOR FAST4 Event,SUR17W0574,Open,31 Mar to 31 Mar,Mens,4,Any - Any
#
# page 21 done!
# next_page exception: Message:
# Screenshot: available via screen
#
# 0
# page 22 done!

# %%
f.close()

# %%
from bs4 import BeautifulSoup as soup
import dryscrape
from urllib.request import urlopen as uReq

# %%
lta_url = 'https://www3.lta.org.uk/Competitions/Search/Search/#/?gen=/3&status=/4/5&grade=/1/2/3/4&page=0'
lta_base_url = 'https://www3.lta.org.uk/Competitions/Search/Search/#/?gen=/3&status=/4/5&grade=/1/2/3/4&page='
uClient = uReq(lta_url)
page_html = uClient.read()
uClient.close()

# %%
session = dryscrape.Session()
session.visit(lta_url)
response = session.body()

# %%
page_soup = soup(page_html, 'html.parser')
page = soup(response, 'html.parser')

# %%
res = page.findAll('div',{'class':'dd'})

# %%
# tournament_container = page_soup.findAll('div',{'class':'lta-competition-results'})
tournamentDiv = res[0].findAll('div',{'class':'dh'})[0]
def getTournamentDetails(tournamentDiv):
    tournament = tournamentDiv.a.text
    tournamentCode = tournamentDiv.span.text
    tournamentLocationDiv = tournamentDiv.findAll('div',{'class':'di'})[0].text
    tournamentType = tournamentDiv.findAll('div',{'class':'dk'})[0].text
    tournamentDate  = tournamentDiv.findAll('div',{'class':'dl'})[0].text
    tournamentSex   = tournamentDiv.findAll('div',{'class':'dp'})[0].text
    tournamentGrade  = tournamentDiv.findAll('div',{'class':'d2'})[0].span.text
    tournamentDetailsLink =  'https://www3.lta.org.uk' + tournamentDiv.findAll('a',{'class':'titled'})[0]['href']
    
    tournamentRating  = res[0].findAll('div',{'class':'d2'})[0].div.text
    # print(tournamentDetailsLink)# + ' , ' + tournament + ',' + tournamentCode + ',' + tournamentType + ',' + tournamentDate + ',' + tournamentSex + ',' + tournamentGrade + ',' + tournamentRating)
    return tournamentDetailsLink +  ' , ' + tournament + ',' + tournamentCode + ',' + tournamentType + ',' + tournamentDate + ',' + tournamentSex + ',' + tournamentGrade + ',' + tournamentRating

# %%
filename = '/home/datadrive/lta_dump/tournaments.csv'
header = 'tournamentDetailsLink' +  ' , ' + 'tournament' + ',' + 'tournamentCode' + ',' + 'tournamentType' + ',' + 'tournamentDate' + ',' + 'tournamentSex' + ',' + 'tournamentGrade' + ',' + 'tournamentRating'
with open(filename, 'w') as f:
    f.write(header)
    
page = 0
itemsOnPage = 10
while (itemsOnPage == 10):
    session = dryscrape.Session()
    session.visit(lta_base_url)
    response = session.body()
    page_soup = soup(page_html, 'html.parser')
    body = soup(response, 'html.parser')
    tournament_containers = body.findAll('div',{'class':'dd'})
    itemsOnPage = len(tournament_containers)
    page +=1
    
 
    for container in tournament_containers:
        file_line = getTournamentDetails(container)
        with open(filename, 'a') as f:
            f.write(file_line)
    print('done!')

# %%
import requests
url_get = requests.get(lta_url)

# %%
stuff = soup(url_get.content, 'html.parser')

# %%
stuff
# Out:
# <!DOCTYPE html>
#
# <html lang="en-gb">
# <head><meta content="IE=edge" http-equiv="X-UA-Compatible"/><title>
# 	Search - LTA
# </title><meta content="Find local UK tennis tournaments and competitions near you with the Lawn Tennis Association - Getting more people playing tennis, more often." name="description"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="tennis competitions, tennis competitions uk, local tennis tournaments, local tennis competitions" id="ctl00_ctl00_ucHeader_metaKeywords" name="keywords"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="type" http-equiv="Content-Script-Type"/>
# <meta content="1597945145" property="twitter:account_id"/>
# <meta content="671360506,808485715,100002324859451,100002315161014,640105886" property="fb:admins"/>
# <meta content="167166273337212" property="fb:app_id"/>
# <link href="/css/components.css" media="screen, projection" rel="stylesheet" title="Default" type="text/css"/>
# <link href="/css/screen.css" media="screen, projection" rel="stylesheet" title="Default" type="text/css"/>
# <link href="/css/major-events.css" media="screen, projection" rel="stylesheet" title="Default" type="text/css"/>
# <link href="/css/cardio-tennis.css" media="screen, projection" rel="stylesheet" title="Default" type="text/css"/>
# <link href="/css/tennis-xpress.css" media="screen, projection" rel="stylesheet" title="Default" type="text/css"/>
# <link href="/css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/css/handheld.css" media="handheld" rel="stylesheet" type="text/css"/>
# <link href="/css/components-legacy.css" media="screen, projection" rel="stylesheet" title="Default" type="text/css"/>
# <link href="/css/overlay/main.css" media="screen, projection" rel="stylesheet" type="text/css"/>
# <!--[if IE]><link rel="stylesheet" type="text/css" href="/css/ie.css" media="screen, projection" title="Default" /><![endif]-->
# <!--[if IE 7]><link rel="stylesheet" type="text/css" href="/css/ie7.css" media="screen, projection" title="Default" /><![endif]-->
# <!--[if IE 8]><link rel="stylesheet" type="text/css" href="/css/ie8.css" media="screen, projection" title="Default" /><![endif]-->
# <!--[if lte IE 6]><link rel="stylesheet" type="text/css" href="/css/ie6.css" media="screen, projection" title="Default" /><![endif]-->
# <script src="/javascript/cookies.js" type="text/javascript"></script>
# <script src="/javascript/FC.js" type="text/javascript"></script>
# <!--script type="text/javascript" src="/javascript/jquery-1.7.2.min.js"></script-->
# <script src="/javascript/jquery.min.js" type="text/javascript"></script>
# <script src="/javascript/jquery.timers.js" type="text/javascript"></script>
# <script src="/javascript/jquery.scrollTo-min.js" type="text/javascript"></script>
# <script src="/javascript/jquery.fc.carousel.js" type="text/javascript"></script>
# <script src="/javascript/swfobject.js" type="text/javascript"></script>
# <script src="/javascript/jwplayer.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var $j = jQuery.noConflict();
#     document.documentElement.className = (document.documentElement.className) ? document.documentElement.className + " js" : "js";
# </script>
# <!--script type="text/javascript" src="/javascript/jquery.hoverIntent.minified.js"></script-->
# <!--ShareThis
# <script type="text/javascript"> var switchTo5x = true;</script>
# <script type="text/javascript" src="https://ws.sharethis.com/button/buttons.js"></script>
# <script type="text/javascript"> stLight.options({ publisher: "01711a2a-6ab0-4a2c-bc91-806867a9af5e", doNotHash: false, doNotCopy: false, hashAddressBar: false });</script>
# End ShareThis-->
# <!-- Pingdom Tracker -->
# <!-- noindex -->
# <script language="JavaScript" type="text/javascript">
#     var _prum = [['id', '52454589abe53dce62000000'],
#              ['mark', 'firstbyte', (new Date()).getTime()]];
#     (function() {
#         var s = document.getElementsByTagName('script')[0]
#       , p = document.createElement('script');
#         p.async = 'async';
#         p.src = '//rum-static.pingdom.net/prum.min.js';
#         s.parentNode.insertBefore(p, s);
#     })();
# </script>
# <!-- /noindex -->
# <!-- Pingdom Tracker -->
# <link href="/css/screen/fonts.css" rel="stylesheet" type="text/css"/>
# <link href="/css/screen/main.css" rel="stylesheet"/>
# <link href="/css/screen/navigation.css" rel="stylesheet"/>
# <link href="/css/screen/footer.css" rel="stylesheet"/>
# <script src="/javascript/scripts/html5shiv.js" type="text/javascript"></script>
# <script src="/javascript/scripts/core.js" type="text/javascript"></script>
# <script src="/javascript/scripts/navigation.js" type="text/javascript"></script>
# <link href="/css/competitions.css?v=1.0" rel="Stylesheet" type="text/css"/>
# <link href="/css/competition-forms.css?v=1.0" rel="Stylesheet" type="text/css"/>
# <link href="/css/jquery.autocomplete.css" rel="Stylesheet" type="text/css"/>
# <link href="/css/thickbox.css" rel="stylesheet" type="text/css"/>
# <link href="/css/competitions-print.css?v=1.0" media="print" rel="Print Stylesheet" type="text/css"/>
# <script src="/javascript/thickbox.js" type="text/javascript"></script>
# <script type="text/javascript">
#         var currUrl = window.location.href.split('Results');
#         if (currUrl[1].indexOf('gen') == -1) {
#             window.location = currUrl[0];
#         }
#     </script>
# </head>
# <!--googleoff: all-->
# <body class="lta-search">
# <div id="fb-root"></div>
# <script type="text/javascript">
#     // Non-blocking asynchronous loading of Facebook initialisation script
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId: '167166273337212',
#             status: true, // check login status
#             cookie: true, // enable cookies to allow the server to access the session
#             xfbml: true   // parse XFBML
#         });
#     };
#     (function() {
#         var e = document.createElement('script');
#         e.src = document.location.protocol + '//connect.facebook.net/en_US/all.js';
#         e.async = true;
#         document.getElementById('fb-root').appendChild(e);
#     } ());
# </script>
# <script language="javascript" type="text/javascript">
#     (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_GB/all.js#xfbml=1";
#         fjs.parentNode.insertBefore(js, fjs);
#     }
#     (document, 'script', 'facebook-jssdk'));
# </script>
# <!--
#     Facebook asynchronous loading initialisation script NEEDS TO BE IMMEDIATELY below BODY tag (can't even add comment there!)
#     else doesn't work in IE!
# -->
# <!-- Facebook recommends initialisation script NEEDS TO BE IMMEDIATELY below BODY tag -->
# <form action="/Competitions/Search/Search/" enctype="multipart/form-data" id="aspnetForm" method="post" name="aspnetForm">
# <div>
# <input id="ctl00_ctl00_LtaScriptManager_HiddenField" name="ctl00_ctl00_LtaScriptManager_HiddenField" type="hidden" value=""/>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <script src="/ScriptResource.axd?d=9-PH7Dahx3GWRYmqOZND0LE3Y_VubdXk-sYGCdsM8TgwhzpNlZYsFnXdCI2hLa3urYdtSYhOKF86zqHRbv0TatCTrYklC-siBSUs8LffxUE1&amp;t=ffffffffa3522211" type="text/javascript"></script>
# <div>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="31E299D7"/>
# </div>
# <!-- Header -->
# <header class="fullClear" id="globalHeader">
# <!-- JS Disabled -->
# <!-- include this if JS is required for any functionality (update text accordingly) -->
# <noscript>
# <div class="noJSMessage">
# <div class="wrap cf">
# <p>You currently have JavaScript disabled in your web browser, please enable JavaScript to view our website as intended.</p>
# <p><a href="http://www.enable-javascript.com/">Here are the instructions of how to enable JavaScript in your browser.</a></p>
# </div>
# </div>
# </noscript>
# <!-- /JS Disabled -->
# <!-- Logos and Navigation -->
# <div id="globalheader">
# <header class="cf" id="globalNavigation">
# <nav class="globalNavigationWrapper wrap">
# <ul id="ctaList">
# <li class="searchminictablock clear">
# <label class="trigger" id="HeaderPlaceHolder_ContentHeader_HeaderMiniCtaBoundProperty_ctl00_ctl01_ctl00_SearchLabel">Search</label>
# <div class="mask flyout ltaSearch" style="">
# <div class="masked" id="HeaderPlaceHolder_ContentHeader_HeaderMiniCtaBoundProperty_ctl00_ctl01_ctl00_SearchPanel">
# <div class="searchTypes">
# <span>Website</span>
# <ul style="">
# <li><a href="#Website" title="Search the LTA">Search the LTA</a></li>
# <li><a href="#Player" title="Player name">Find a Player</a></li>
# <li><a href="#Competition" title="Enter a postcode">Find a Competition</a></li>
# <li><a href="#Coach" title="Enter a postcode">Find a Coach</a></li>
# <li><a href="#Court" title="Enter a county or postcode">Find a Court</a></li>
# </ul>
# </div>
# <input class="focus" placeholder="Search the LTA" type="search"/>
# <input class="btn hidden" data-searchtype="#Website" onclick="return postback(this);" type="submit" value="Search"/>
# </div>
# </div>
# </li>
# <li class="Sitemap_navItem"><a href="https://www.lta.org.uk/site-map/" id="Sitemap_link">Sitemap</a></li>
# <li class="loginminictablock clear">
# <a class="join" data-mobile-text="Join" href="http://www.lta.org.uk/member/" id="ctl00_ctl00_ucMainHeader_UserDetails_HyperLinkSignUp">Become a member</a>
# <a class="login" href="https://www.lta.org.uk/member/login/?DestinationUrl=https%3a%2f%2fwww3.lta.org.uk%2fCompetitions%2fSearch%2fSearch%2f" id="ctl00_ctl00_ucMainHeader_UserDetails_HyperLinkLogin">Login</a>
# </li>
# </ul>
# </nav>
# <!-- /.globalNavigationWrapper -->
# </header>
# <header class="cf" id="primaryNavigation">
# <div class="primaryNav">
# <div class="wrap cf">
# <div class="logo">
# <div class="imageblock clear">
# <a href="https://www.lta.org.uk/" target="_self" title="">
# <img alt="" src="https://live-lta.fastcdn.co.uk/globalassets/global/lta-logo-landscape.png?version=45a4ee9b" title=""/>
# </a>
# </div>
# </div>
# <div class="brandlogo">
# <div class="imageblock clear">
# <a href="http://www.aegontennis.co.uk/" target="_blank" title="">
# <img alt="" src="https://live-lta.fastcdn.co.uk/globalassets/global/aegon-logo.png?version=45a4ee96" title=""/>
# </a>
# </div>
# </div>
# <!-- Main Navigation -->
# <nav class="main">
# <ul></ul>
# </nav>
# </div>
# </div>
# </header>
# </div>
# </header>
# <div class="lta-container clear">
# <div class="lta-competitions-subnav">
# <ul>
# <li class="lta-first"><a href="javascript:__doPostBack('ctl00$ctl00$MainContentPlaceHolder$ctl00$LinkButtonMiniTennis','')" id="ctl00_ctl00_MainContentPlaceHolder_ctl00_LinkButtonMiniTennis" rel="gen:/0">Mini Tennis 5-10 yrs</a></li>
# <li><a href="javascript:__doPostBack('ctl00$ctl00$MainContentPlaceHolder$ctl00$LinkButtonBoys','')" id="ctl00_ctl00_MainContentPlaceHolder_ctl00_LinkButtonBoys" rel="gen:/1">Boys' 11-18 yrs</a></li>
# <li><a href="javascript:__doPostBack('ctl00$ctl00$MainContentPlaceHolder$ctl00$LinkButtonGirls','')" id="ctl00_ctl00_MainContentPlaceHolder_ctl00_LinkButtonGirls" rel="gen:/2">Girls' 11-18 yrs</a></li>
# <li><a href="javascript:__doPostBack('ctl00$ctl00$MainContentPlaceHolder$ctl00$LinkButtonMens','')" id="ctl00_ctl00_MainContentPlaceHolder_ctl00_LinkButtonMens" rel="gen:/3">Men</a></li>
# <li><a href="javascript:__doPostBack('ctl00$ctl00$MainContentPlaceHolder$ctl00$LinkButtonWomens','')" id="ctl00_ctl00_MainContentPlaceHolder_ctl00_LinkButtonWomens" rel="gen:/4">Women</a></li>
# </ul>
# </div>
# <div class="lta-padding lta-clear">
# <a id="skip-content" name="skip-content"></a>
# <!--googleon: all-->
# <input id="page_is_dirty" name="page_is_dirty" type="hidden" value="0"/>
# <div class="lta-event-listing lta-clear">
# <div class="lta-competitions-content clear">
# <div class="lta-padding">
# <div class="lta-competitions-search-header-options">
# <div class="lta-filters-bar clear">
# <div class="lta-save-print">
# <a class="lta-download" title="Download results to CSV"> </a> <a class="lta-print" onclick="window.print();" title="Print"> </a>
# <a class="lta-clear-all-filters">Clear all</a>
# </div>
# </div>
# <div class="lta-competitions-search-nav-bar">
# <h3 class="hide">
# </h3>
# <div class="lta-clear">
# <div class="lta-competitions-filter hide">
# <div class="lta-filter-location lta-form lta-form-wht">
# <div class="lta-form-row lta-clear">
# <div class="lta-form-field-b">
# <label>
#                                                 Sort by</label>
# <span class="lta-input-select">
# <select rel="sortBy">
# <option value="0">Date - Ascending</option>
# <option value="1">Date - Descending</option>
# <option value="2">Distance - Closest</option>
# </select>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="lta-competitions-filter hide">
# <div class="lta-filter-location lta-form lta-form-wht-two">
# <div class="lta-form-row lta-clear">
# <div class="lta-form-field-b">
# <label>
#                                                 View</label>
# <span class="lta-input-select">
# <select rel="pageSize">
# <option value="10">10 per page</option>
# <option value="20">20 per page</option>
# <option value="30">30 per page</option>
# <option value="40">40 per page</option>
# <option value="50">50 per page</option>
# </select>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="lta-comp-pagination">
# </div>
# </div>
# </div>
# </div>
# <div class="lta-competition-results">
# </div>
# <div class="lta-competitions-search-bottom">
# </div>
# <br/>
# <hr noshade="noshade" size="1"/>
# <p>
#                     (*) Distances are calculated "<strong>as the crow flies</strong>" for
#                     a more accurate representation please use the "<strong>get directions</strong>"
#                     feature on the competition overview page.</p>
# <div class="lta-back-to-top hide">
# <a href="#top">^ back to top ^</a></div>
# </div>
# </div>
# <div class="lta-competitions-additional">
# <div id="ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_SiteBComposerCopy">
# </div>
# <div class="lta-padding">
# <div class="lta-box lta-box-green lta-course-listing">
# <div class="lta-box-top">
# <div class="lta-box-top-right">
# </div>
# </div>
# <div class="lta-box-middle">
# <div class="lta-box-padding lta-detailed-listing">
# <div class="lta-header lta-clear">
# <h2>
#                                         Not logged in</h2>
# </div>
# <p>
#                                     It's easier finding competitions if you log in. You'll see relevant competitions
#                                     for your age and location and you'll see more information about the tournament.
#                                 </p>
# <p>
# <a class="lta-login-now-btn" href="https://www.lta.org.uk/member/login/?DestinationUrl=https%3a%2f%2fwww3.lta.org.uk%2fCompetitions%2fSearch%2fSearch%2f" id="ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_HyperLinkLoginNow">Login now</a>
# </p>
# </div>
# </div>
# <div class="lta-box-bottom">
# <div class="lta-box-bottom-right">
# </div>
# </div>
# </div>
# </div>
# <div class="lta-padding">
# <div class="lta-box lta-box32 lta-form lta-form-tiny">
# <div class="lta-comp-search-header lta-clear">
# <div class="lta-comp-search-header-top">
# </div>
# <div class="lta-comp-search-header-middle">
# <div>
# <h2>
# <a class="lta-btn-alt lta-btn-alt-3 lta-refine-search lta-disabled" href="#"><span>Update</span></a>
#                                     Refine your<br/>
#                                     search
#                                 </h2>
# </div>
# </div>
# <div class="lta-comp-search-header-bottom">
# </div>
# </div>
# <div class="lta-box-middle">
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Location</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body lta-location-filter clear">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <div class="lta-form-row lta-clear lta-location-selector">
# <div class="lta-location-selected-options hide">
# </div>
# <div class="lta-location-proximity hide">
# <label for="text-input-alt-1">
#                                             Enter place or postcode:
#                                         </label>
# <div class="lta-form-field">
# <span class="lta-input-text">
# <input id="text1" name="text-input-alt-alt-1" rel="location" type="text"/>
# </span>
# </div>
# <div class="lta-form-field">
# <label class="lta-within-distance">
#                                                 Within
#                                             </label>
# <span class="lta-input-select">
# <select rel="distance">
# <option value="5">5 miles</option>
# <option value="10">10 miles</option>
# <option value="20">20 miles</option>
# <option value="30">30 miles</option>
# <option value="40">40 miles</option>
# <option value="50">50 miles</option>
# <option value="75">75 miles</option>
# <option selected="selected" value="100">100 miles</option>
# <option value="150">150 miles</option>
# <option value="200">200 miles</option>
# <option value="250">250 miles</option>
# <option value="500">500 miles</option>
# <option value="1000">Any distance</option>
# </select>
# </span>
# </div>
# </div>
# <a class="lta-choose-more-link" href="#lta-event-overlay-location"></a>
# </div>
# </div>
# </div>
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Date</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body clear lta-date-filter">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <div class="lta-form-row lta-clear lta-datepicker">
# <!-- Datepicker 1 -->
# <div class="lta-datepicker-field">
# <label for="date-input-1">
#                                             From:
#                                         </label>
# <div class="lta-form-field">
# <span class="lta-input-text lta-input-date">
# <input autocomplete="off" class="lta-date-from" id="date-input-1" name="date-input-1" placeholder="DD/MM/YYYY" rel="dateFrom" type="text"/>
# </span><a class="lta-datepicker-icon" href="#">
# <img alt="Select date..." src="/images/competitions/icons/date-picker.gif"/>
# </a>
# </div>
# </div>
# </div>
# <div class="lta-form-row lta-clear lta-datepicker">
# <!-- Datepicker 2 -->
# <div class="lta-datepicker-field">
# <label for="date-input-2">
#                                             To:
#                                         </label>
# <div class="lta-form-field">
# <span class="lta-input-text lta-input-date">
# <input autocomplete="off" class="lta-date-to" id="date-input-2" name="date-input-2" placeholder="DD/MM/YYYY" rel="dateTo" type="text"/>
# </span><a class="lta-datepicker-icon" href="#">
# <img alt="Select date..." src="/images/competitions/icons/date-picker.gif"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Grade</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body clear">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <ul class="lta-clear lta-grade-filter">
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-grade1" name="checkbox-grade1" rel="grade:/1" type="checkbox"/></span>
# <label for="checkbox-grade1">
#                                                 Grade 1 - National Level</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-grade2" name="checkbox-grade2" rel="grade:/2" type="checkbox"/></span>
# <label for="checkbox-grade2">
#                                                 Grade 2 - National Level</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-grade3" name="checkbox-grade3" rel="grade:/3" type="checkbox"/></span>
# <label for="checkbox-grade3">
#                                                 Grade 3 - Regional Level</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-grade4" name="checkbox-grade4" rel="grade:/4" type="checkbox"/></span>
# <label for="checkbox-grade4">
#                                                 Grade 4 - County Level</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-grade5" name="checkbox-grade5" rel="grade:/5" type="checkbox"/></span>
# <label for="checkbox-grade5">
#                                                 Grade 5 - Local Level</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-grade6" name="checkbox-grade6" rel="grade:/6" type="checkbox"/></span>
# <label for="checkbox-grade6">
#                                                 Grade 6 - Local Level</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-grade7" name="checkbox-grade7" rel="grade:/7" type="checkbox"/></span>
# <label for="checkbox-grade7">
#                                                 Grade 7 - Club Internal Level</label>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Age</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body clear">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <ul class="lta-clear lta-mini-age-group">
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U8" name="checkbox-U8" rel="age:/3" type="checkbox"/></span>
# <label for="checkbox-U8">
#                                                 8 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U9" name="checkbox-U9" rel="age:/4" type="checkbox"/></span>
# <label for="checkbox-U9">
#                                                 9 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U10" name="checkbox-U10" rel="age:/5" type="checkbox"/></span>
# <label for="checkbox-U10">
#                                                 10 and under</label>
# </div>
# </li>
# </ul>
# <ul class="lta-clear lta-teen-age-group">
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U11" name="checkbox-U11" rel="age:/6" type="checkbox"/></span>
# <label for="checkbox-U11">
#                                                 11 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U12" name="checkbox-U12" rel="age:/7" type="checkbox"/></span>
# <label for="checkbox-U12">
#                                                 12 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U13" name="checkbox-U13" rel="age:/8" type="checkbox"/></span>
# <label for="checkbox-U13">
#                                                 13 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U14" name="checkbox-U14" rel="age:/9" type="checkbox"/></span>
# <label for="checkbox-U14">
#                                                 14 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U15" name="checkbox-U15" rel="age:/10" type="checkbox"/></span>
# <label for="checkbox-U15">
#                                                 15 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U16" name="checkbox-U16" rel="age:/11" type="checkbox"/></span>
# <label for="checkbox-U16">
#                                                 16 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U17" name="checkbox-U17" rel="age:/12" type="checkbox"/></span>
# <label for="checkbox-U17">
#                                                 17 and under</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-U18" name="checkbox-U18" rel="age:/13" type="checkbox"/></span>
# <label for="checkbox-U18">
#                                                 18 and under</label>
# </div>
# </li>
# </ul>
# <ul class="lta-clear lta-open-age-group">
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-open" name="checkbox-open" rel="age:/0" type="checkbox"/></span>
# <label for="checkbox-open">
#                                                 Open</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-30" name="checkbox-30" rel="age:/17" type="checkbox"/></span>
# <label for="checkbox-30">
#                                                 30+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-35" name="checkbox-35" rel="age:/18" type="checkbox"/></span>
# <label for="checkbox-35">
#                                                 35+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-40" name="checkbox-40" rel="age:/19" type="checkbox"/></span>
# <label for="checkbox-40">
#                                                 40+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-45" name="checkbox-45" rel="age:/20" type="checkbox"/></span>
# <label for="checkbox-45">
#                                                 45+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-50" name="checkbox-50" rel="age:/21" type="checkbox"/></span>
# <label for="checkbox-50">
#                                                 50+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-55" name="checkbox-55" rel="age:/22" type="checkbox"/></span>
# <label for="checkbox-55">
#                                                 55+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-60" name="checkbox-60" rel="age:/23" type="checkbox"/></span>
# <label for="checkbox-60">
#                                                 60+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-65" name="checkbox-65" rel="age:/24" type="checkbox"/></span>
# <label for="checkbox-65">
#                                                 65+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-70" name="checkbox-70" rel="age:/25" type="checkbox"/></span>
# <label for="checkbox-70">
#                                                 70+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-75" name="checkbox-75" rel="age:/26" type="checkbox"/></span>
# <label for="checkbox-75">
#                                                 75+</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-80" name="checkbox-80" rel="age:/27" type="checkbox"/></span>
# <label for="checkbox-80">
#                                                 80+</label>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Gender</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body clear">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <ul class="lta-clear">
# <li class="lta-gender-male">
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-male" name="checkbox-male" rel="gdr:/0" type="checkbox"/></span>
# <label for="checkbox-male">
#                                                 Male</label>
# </div>
# </li>
# <li class="lta-gender-female">
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-female" name="checkbox-female" rel="gdr:/1" type="checkbox"/></span>
# <label for="checkbox-female">
#                                                 Female</label>
# </div>
# </li>
# <li class="lta-gender-mixed">
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-mixed" name="checkbox-mixed" rel="gdr:/2" type="checkbox"/></span>
# <label for="checkbox-mixed">
#                                                 Mixed</label>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Event Type</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body clear">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <ul class="lta-clear">
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-singles" name="checkbox-singles" rel="event:/0" type="checkbox"/></span>
# <label for="checkbox-singles">
#                                                 Singles</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-doubles" name="checkbox-doubles" rel="event:/1" type="checkbox"/></span>
# <label for="checkbox-doubles">
#                                                 Doubles</label>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Category</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body clear">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <ul class="lta-category-filter">
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-british" name="checkbox-british" rel="cat:/00" type="checkbox"/></span>
# <label for="checkbox-british">
#                                                 British Tour</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-county-closed" name="checkbox-county-closed" rel="cat:/01" type="checkbox"/></span>
# <label for="checkbox-county-closed">
#                                                 County Closed</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-county" name="checkbox-county" rel="cat:/02" type="checkbox"/></span>
# <label for="checkbox-county">
#                                                 County Tour</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-disability" name="checkbox-disability" rel="cat:/03" type="checkbox"/></span>
# <label for="checkbox-disability">
#                                                 Disability</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-club-matches" name="checkbox-club-matches" rel="cat:/04" type="checkbox"/></span>
# <label for="checkbox-club-matches">
#                                                 Internal Matches</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-plays" name="checkbox-plays" rel="cat:/05" type="checkbox"/></span>
# <label for="checkbox-plays">
#                                                 Match Play</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-junior" name="checkbox-junior" rel="cat:/06" type="checkbox"/></span>
# <label for="checkbox-junior">
#                                                 National Junior Champs</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-national" name="checkbox-national" rel="cat:/07" type="checkbox"/></span>
# <label for="checkbox-national">
#                                                 National Tour</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-open-cat" name="checkbox-open-cat" rel="cat:/08" type="checkbox"/></span>
# <label for="checkbox-open-cat">
#                                                 Open</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-regional" name="checkbox-regional" rel="cat:/09" type="checkbox"/></span>
# <label for="checkbox-regional">
#                                                 Regional tour</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-wimbledon" name="checkbox-wimbledon" rel="cat:/10" type="checkbox"/></span>
# <label for="checkbox-wimbledon">
#                                                 Road to Wimbledon</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-vets" name="checkbox-vets" rel="cat:/11" type="checkbox"/></span>
# <label for="checkbox-vets">
#                                                 Seniors</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-uni" name="checkbox-uni" rel="cat:/12" type="checkbox"/></span>
# <label for="checkbox-uni">
#                                                 University</label>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="lta-competition-filter-category">
# <div class="lta-competition-filter-category-header">
# <h2 class="lta-border-remove">
# <a class="lta-competition-category-open" href="#"></a><span>Status</span>
# </h2>
# </div>
# <div class="lta-competition-filter-category-body clear">
# <a class="lta-competition-filter-category-body-clear" href="#">clear</a>
# <ul class="lta-clear">
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-upcoming" name="checkbox-upcoming" rel="status:/4" type="checkbox"/></span>
# <label for="checkbox-upcoming">
#                                                 Upcoming</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-accepting" name="checkbox-accepting" rel="status:/5" type="checkbox"/></span>
# <label for="checkbox-accepting">
#                                                 Accepting entries</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-closed" name="checkbox-closed" rel="status:/6" type="checkbox"/></span>
# <label for="checkbox-closed">
#                                                 Closed for entries</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-withdraw" name="checkbox-withdraw" rel="status:/7" type="checkbox"/></span>
# <label for="checkbox-withdraw">
#                                                 Withdrawal date passed</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-progress" name="checkbox-progress" rel="status:/8" type="checkbox"/></span>
# <label for="checkbox-progress">
#                                                 In progress</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-pending" name="checkbox-pending" rel="status:/9" type="checkbox"/></span>
# <label for="checkbox-pending">
#                                                 Pending results</label>
# </div>
# </li>
# <li>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-results" name="checkbox-results" rel="status:/10" type="checkbox"/></span>
# <label for="checkbox-results">
#                                                 Results available</label>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lta-refine-bottom">
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--googleoff: all-->
# </div>
# <script language="javascript" type="text/javascript">
#     function ShowCommentPopUp(eventId, playerId, comment) {
#         document.getElementById("ctl00_ctl00_MainContentPlaceHolder_commentPopUp_HiddenFieldEventId").value = eventId;
#         document.getElementById("ctl00_ctl00_MainContentPlaceHolder_commentPopUp_HiddenFieldPlayerId").value = playerId;
#         document.getElementById("ctl00_ctl00_MainContentPlaceHolder_commentPopUp_HiddenFieldComment").value = comment;
#         document.getElementById("ctl00_ctl00_MainContentPlaceHolder_commentPopUp_PanelFields").className = "show";
#         document.getElementById("ctl00_ctl00_MainContentPlaceHolder_commentPopUp_lblCommentValidator").className = "hide";
#         document.getElementById("ctl00_ctl00_MainContentPlaceHolder_commentPopUp_PanelConfirmation").className = "hide";
#
#         tb_show("", "#TB_inline?inlineId=commentPopUp&height=395&width=420&modal=true", null);
#
#         return false;
#     }
# </script>
# <style type="text/css">
#     #TB_window
#     {
#         background-color: transparent;
#     }
# </style>
# <input id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_HiddenFieldComment" name="ctl00$ctl00$MainContentPlaceHolder$commentPopUp$HiddenFieldComment" type="hidden"/>
# <input id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_HiddenFieldEventId" name="ctl00$ctl00$MainContentPlaceHolder$commentPopUp$HiddenFieldEventId" type="hidden"/>
# <input id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_HiddenFieldPlayerId" name="ctl00$ctl00$MainContentPlaceHolder$commentPopUp$HiddenFieldPlayerId" type="hidden"/>
# <div id="commentPopUp">
# <div class="commentPopUp">
# <div class="header clear">
# <h3 class="floatleft">
#                 Add Comment</h3>
# <a class="teaserlink floatright" href="#" id="TB_closeWindowButton">Close</a>
# </div>
# <div id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_upComments">
# <div class="show" id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_PanelFields">
# <p>
#                         The comments box is for adding requested/essential information such as your ITF ranking or preference, where a choice has been offered. You should contact the competition organiser direct for general enquiries.</p>
# <div class="tall-field clear">
# <div class="label">
# <label for="lblComment">
#                                 Comment:</label>
# </div>
# <div class="element">
# <textarea id="txtComment" onchange="document.getElementById('ctl00_ctl00_MainContentPlaceHolder_commentPopUp_HiddenFieldComment').value = this.value;"></textarea>
# </div>
# <span class="hide" id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_lblCommentValidator">*</span>
# </div>
# <div class="field clear">
# <div class="label">
#                              </div>
# <div class="element">
# <a href="javascript:__doPostBack('ctl00$ctl00$MainContentPlaceHolder$commentPopUp$LinkButtonSubmit','')" id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_LinkButtonSubmit">
# <img alt="Save" src="/images/btn_submit.gif"/>
# </a>
# </div>
# </div>
# </div>
# <div class="hide" id="ctl00_ctl00_MainContentPlaceHolder_commentPopUp_PanelConfirmation">
# <p>
#                         Thank you, your comments have been added to your entry and will be picked up by the Tournament Organiser/Referee.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="cf" id="globalFooterNew">
# <div class="fullClear">
# <nav class="breadcrumbsNav breadcrumbrowblockNew">
# <div class="breadcrumbrowblock wrap">
# <div class="breadcrumbrightbox cf"><span class="backtotop" onclick="$j('body, html').animate({ scrollTop: 0 });">Back To Top</span></div>
# <div class="fullClear"></div>
# </div>
# </nav>
# <!-- /.breadcrumbrowblockNew -->
# <div class="wrap12">
# <div class="footerlinksrowblock cf">
# <div class="box1 tc top">
# <img alt="LTA Logo" src="https://www.lta.org.uk/globalassets/global/lta-logo-landscape.png" style="max-width: 120px;" title="LTA"/>
# </div>
# <div class="box5 tc top">
# <div class="contentLinks">
# <div class="noBullets">FOLLOW US</div>
# <div class="socialLinks">
# <ul class="noBullets">
# <li class="imageblock clear">
# <a href="http://www.twitter.com/BritishTennis" target="_blank" title="Twitter Icon">
# <img alt="" src="https://live-lta.fastcdn.co.uk/globalassets/global/twitter.png?version=45a4ee9b" title=""/>
# </a>
# </li>
# <li class="imageblock clear">
# <a href="http://www.facebook.com/britishtennislta" target="_blank" title="Facebook Icon">
# <img alt="" src="https://live-lta.fastcdn.co.uk/globalassets/global/facebook.png?version=45a4ee96" title=""/>
# </a>
# </li>
# <li class="imageblock clear">
# <a href="http://www.youtube.com/user/britishtennislta" target="_blank" title="You Tube">
# <img alt="" src="https://live-lta.fastcdn.co.uk/globalassets/global/youtube.png?version=45a4ee9b" title=""/>
# </a>
# </li>
# <li class="imageblock clear">
# <a href="http://www.instagram.com/britishtennis" target="_blank" title="Instagram Icon">
# <img alt="" src="https://live-lta.fastcdn.co.uk/globalassets/global/instagram.png?version=45a4ee96" title=""/>
# </a>
# </li>
# </ul>
# </div>
# <!-- /socialLinks -->
# </div>
# <!-- /.contentLinks -->
# </div>
# </div>
# <!-- /.footerlinksrowblock -->
# </div>
# <div class="fullClear sponsors">
# </div>
# <!-- /.fullClear.sponsors -->
# </div>
# <div class="footersignoffrowblock">
# <hr/>
# <p>© Copyright 2017 Lawn Tennis Association | British Tennis<span><a href="/site-map/">Site Map</a><a href="/Footer/Privacy-Policy/">Privacy &amp; Cookies</a><a href="/websiteterms">Terms &amp; Conditions</a></span></p>
# </div>
# </footer>
# <div class="lta-userbar lta-not-logged-in" id="ctl00_ctl00_AdditionalFooterPlaceHolder_AdditionalFooterPlaceHolder_ToolBar_HtmlControlUserBar">
# <div class="lta-clear">
# <div class="lta-userbar-users">
# <!-- Current user -->
# <div class="lta-userbar-user lta-clear">
# <img alt="" src="/images/competitions/user-thumb.png"/>
# <div class="lta-userbar-userinfo">
# <h4>Not logged in</h4>
# <a href="https://www.lta.org.uk/member/login/?DestinationUrl=https%3a%2f%2fwww3.lta.org.uk%2fCompetitions%2fSearch%2fSearch%2f&amp;mode=1">Log in now, it's easier</a>
# </div>
# </div>
# </div>
# <ul class="lta-userbar-actions">
# <li class="lta-userbar-cal">
# <a href="/Competitions/Calendar/">
# <span>Competition calendar</span>
# </a>
# </li>
# <li class="lta-userbar-basket lta-userbar-selected">
# <a href="/Competitions/Basket/">
# <span>Basket (<label class="basket-items"></label>)</span>
# </a>
# </li>
# </ul>
# <div class="lta-userbar-search">
# <div>
# <input id="ctl00_ctl00_AdditionalFooterPlaceHolder_AdditionalFooterPlaceHolder_ToolBar_HiddenFieldTournament" name="ctl00$ctl00$AdditionalFooterPlaceHolder$AdditionalFooterPlaceHolder$ToolBar$HiddenFieldTournament" type="hidden"/>
# <input class="lta-autocomplete-userbar lta-placeholder-text" id="ctl00_ctl00_AdditionalFooterPlaceHolder_AdditionalFooterPlaceHolder_ToolBar_TextBoxTournament" name="ctl00$ctl00$AdditionalFooterPlaceHolder$AdditionalFooterPlaceHolder$ToolBar$TextBoxTournament" title="Tournament code or name" type="text"/>
# </div>
# <a href="javascript:__doPostBack('ctl00$ctl00$AdditionalFooterPlaceHolder$AdditionalFooterPlaceHolder$ToolBar$LinkButtonTournamentGo','')" id="ctl00_ctl00_AdditionalFooterPlaceHolder_AdditionalFooterPlaceHolder_ToolBar_LinkButtonTournamentGo">Go</a>
# </div>
# <div class="lta-basket-notification">
# <div class="lta-box-top"><div class="lta-box-top-right"></div></div>
# <div class="lta-box-sides">
# <div class="lta-box-middle lta-clear">
# <p><label>The item</label> has been added <span></span></p>
# <img alt="Notification" height="20" src="/images/competitions/icons/notification-icon.png" width="31"/>
# </div>
# </div>
# <div class="lta-box-bottom"><div class="lta-box-bottom-right"></div></div>
# </div>
# </div>
# </div>
# </form>
# <script src="/javascript/functions-legacy.js" type="text/javascript"></script>
# <script src="/javascript/functions.js" type="text/javascript"></script>
# <script src="/javascript/functions-validation.js" type="text/javascript"></script>
# <script src="/javascript/functions-competitions.js?v=1.0" type="text/javascript"></script>
# <script src="/javascript/jquery.tooltip.js" type="text/javascript"></script>
# <script src="/javascript/jquery.timers.js" type="text/javascript"></script>
# <script src="/javascript/jquery.autocomplete.js" type="text/javascript"></script>
# <div class="lta-event-selection-overlay lta-form lta-form-alternate">
# <div class="lta-event-selection-overlay-content">
# <a class="lta-event-overlay-close" href="#">Close x</a>
# <div class="lta-event-overlay-body clear">
# <div class="lta-event-overlay-content lta-competition-filter-category-body">
# <div class="lta-event-content" id="lta-event-overlay-location">
# <div class="lta-location-nav-tabs clear">
# <h2 class="by-county-nav">
# <a href="#">By county</a></h2>
# <h2 class="by-region-nav">
# <a href="#">By region</a></h2>
# <h2 class="by-location-nav">
# <a href="#">By location</a></h2>
# <h2 class="by-club-nav">
# <a href="#">By club</a></h2>
# </div>
# <div class="by-county hide">
# <div class="lta-event-location-col">
# <h3>
#                                     ENGLAND</h3>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-avon" name="checkbox-avon" rel="county:/00" type="checkbox"/></span>
# <label for="checkbox-avon">
#                                         Avon</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-befordshire" name="checkbox-bedfordshire" rel="county:/01" type="checkbox"/></span>
# <label for="checkbox-befordshire">
#                                         Bedfordshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-berkshire" name="checkbox-berkshire" rel="county:/02" type="checkbox"/></span>
# <label for="checkbox-berkshire">
#                                         Berkshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-bucks" name="checkbox-bucks" rel="county:/03" type="checkbox"/></span>
# <label for="checkbox-bucks">
#                                         Buckinghamshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-cambs" name="checkbox-cambs" rel="county:/04" type="checkbox"/></span>
# <label for="checkbox-cambs">
#                                         Cambridgeshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-cheshire" name="checkbox-cheshire" rel="county:/06" type="checkbox"/></span>
# <label for="checkbox-cheshire">
#                                         Cheshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-cornwall" name="checkbox-cornwall" rel="county:/07" type="checkbox"/></span>
# <label for="checkbox-cornwall">
#                                         Cornwall</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-cumbria" name="checkbox-cumbria" rel="county:/08" type="checkbox"/></span>
# <label for="checkbox-cumbria">
#                                         Cumbria</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-derbyshire" name="checkbox-derbyshire" rel="county:/09" type="checkbox"/></span>
# <label for="checkbox-derbyshire">
#                                         Derbyshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-devon" name="checkbox-devon" rel="county:/10" type="checkbox"/></span>
# <label for="checkbox-devon">
#                                         Devon</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-dorset" name="checkbox-dorset" rel="county:/11" type="checkbox"/></span>
# <label for="checkbox-dorset">
#                                         Dorset</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-durham" name="checkbox-durham" rel="county:/12" type="checkbox"/></span>
# <label for="checkbox-durham">
#                                         Durham &amp; Cleveland</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-essex" name="checkbox-essex" rel="county:/13" type="checkbox"/></span>
# <label for="checkbox-essex">
#                                         Essex</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-gloucestershire" name="checkbox-gloucestershire" rel="county:/14" type="checkbox"/></span>
# <label for="checkbox-gloucestershire">
#                                         Gloucestershire</label>
# </div>
# </div>
# <div class="lta-event-location-col">
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-hampshire" name="checkbox-hampshire" rel="county:/15" type="checkbox"/></span>
# <label for="checkbox-hampshire">
#                                         Hampshire &amp; Isle of Wight</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-herefordshire" name="checkbox-herefordshire" rel="county:/16" type="checkbox"/></span>
# <label for="checkbox-herefordshire">
#                                         Herefordshire &amp; Worcestershire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-herts" name="checkbox-herts" rel="county:/17" type="checkbox"/></span>
# <label for="checkbox-herts">
#                                         Hertfordshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-kent" name="checkbox-kent" rel="county:/19" type="checkbox"/></span>
# <label for="checkbox-kent">
#                                         Kent</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-lancs" name="checkbox-lancs" rel="county:/20" type="checkbox"/></span>
# <label for="checkbox-lancs">
#                                         Lancashire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-leicestershire" name="checkbox-leicestershire" rel="county:/21" type="checkbox"/></span>
# <label for="checkbox-leicestershire">
#                                         Leicestershire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-lincolnshire" name="checkbox-lincolnshire" rel="county:/22" type="checkbox"/></span>
# <label for="checkbox-lincolnshire">
#                                         Lincolnshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-middlesex" name="checkbox-middlesex" rel="county:/23" type="checkbox"/></span>
# <label for="checkbox-middlesex">
#                                         Middlesex</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-norfolk" name="checkbox-norfolk" rel="county:/24" type="checkbox"/></span>
# <label for="checkbox-norfolk">
#                                         Norfolk</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-northamptonshire" name="checkbox-northamptonshire" rel="county:/25" type="checkbox"/></span>
# <label for="checkbox-northamptonshire">
#                                         Northamptonshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-northumberland" name="checkbox-northumberland" rel="county:/26" type="checkbox"/></span>
# <label for="checkbox-northumberland">
#                                         Northumberland</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-nottinghamshire" name="checkbox-nottinghamshire" rel="county:/27" type="checkbox"/></span>
# <label for="checkbox-nottinghamshire">
#                                         Nottinghamshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-oxfordshire" name="checkbox-oxfordshire" rel="county:/28" type="checkbox"/></span>
# <label for="checkbox-oxfordshire">
#                                         Oxfordshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-shropshire" name="checkbox-shropshire" rel="county:/30" type="checkbox"/></span>
# <label for="checkbox-shropshire">
#                                         Shropshire</label>
# </div>
# </div>
# <div class="lta-event-location-col lta-event-location-last-col">
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-somerset" name="checkbox-somerset" rel="county:/31" type="checkbox"/></span>
# <label for="checkbox-somerset">
#                                         Somerset</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-staffordshire" name="checkbox-staffordshire" rel="county:/32" type="checkbox"/></span>
# <label for="checkbox-staffordshire">
#                                         Staffordshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-suffolk" name="checkbox-suffolk" rel="county:/33" type="checkbox"/></span>
# <label for="checkbox-suffolk">
#                                         Suffolk</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-surrey" name="checkbox-surrey" rel="county:/34" type="checkbox"/></span>
# <label for="checkbox-surrey">
#                                         Surrey</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-sussex" name="checkbox-sussex" rel="county:/35" type="checkbox"/></span>
# <label for="checkbox-sussex">
#                                         Sussex</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-warwickshire" name="checkbox-warwickshire" rel="county:/37" type="checkbox"/></span>
# <label for="checkbox-warwickshire">
#                                         Warwickshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-wiltshire" name="checkbox-wiltshire" rel="county:/38" type="checkbox"/></span>
# <label for="checkbox-wiltshire">
#                                         Wiltshire</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-yorkshire" name="checkbox-yorkshire" rel="county:/39" type="checkbox"/></span>
# <label for="checkbox-yorkshire">
#                                         Yorkshire</label>
# </div>
# <h3 class="clear">
#                                     ISLAND ASSOCIATIONS</h3>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-channelislands" name="checkbox-channelislands" rel="county:/5" type="checkbox"/></span>
# <label for="checkbox-channelislands">
#                                         Channel Islands</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-isleOfMan" name="checkbox-isleOfMan" rel="county:/18" type="checkbox"/></span>
# <label for="checkbox-isleOfMan">
#                                         Isle of Man</label>
# </div>
# <div class="lta-clear">
#                                      </div>
# <div class="lta-other-locations lta-clear">
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-scotland" name="checkbox-scotland" rel="county:/29" type="checkbox"/></span>
# <label for="checkbox-scotland">
#                                             Tennis Scotland</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-wales" name="checkbox-wales" rel="county:/36" type="checkbox"/></span>
# <label for="checkbox-wales">
#                                             Tennis Wales</label>
# </div>
# </div>
# </div>
# </div>
# <div class="by-region hide">
# <div class="lta-event-location-col lta-event-location-last-col">
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-east" name="checkbox-east" rel="region:/0" type="checkbox"/></span>
# <label for="checkbox-east">
#                                         East</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-midlands" name="checkbox-midlands" rel="region:/1" type="checkbox"/></span>
# <label for="checkbox-midlands">
#                                         Midlands</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-north" name="checkbox-north" rel="region:/2" type="checkbox"/></span>
# <label for="checkbox-north">
#                                         North</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-southeast" name="checkbox-southeast" rel="region:/3" type="checkbox"/></span>
# <label for="checkbox-southeast">
#                                         South East</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-southwest" name="checkbox-southwest" rel="region:/4" type="checkbox"/></span>
# <label for="checkbox-southwest">
#                                         South West</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-rscotland" name="checkbox-rscotland" rel="region:/5" type="checkbox"/></span>
# <label for="checkbox-rscotland">
#                                         Tennis Scotland</label>
# </div>
# <div class="lta-form-field">
# <span class="lta-input-checkbox">
# <input class="lta-checkbox-custom" id="checkbox-rwales" name="checkbox-rwales" rel="region:/6" type="checkbox"/></span>
# <label for="checkbox-rwales">
#                                         Tennis Wales</label>
# </div>
# </div>
# </div>
# <div class="by-location hide">
# <div class="lta-competition-filter-category-body clear">
# <div class="lta-form-row lta-clear lta-location-selector">
# <div class="lta-form-field">
# <label class="lta-within-distance">
#                                             Within
#                                         </label>
# <span class="lta-input-select">
# <select rel="distance">
# <option value="5">5 miles</option>
# <option value="10">10 miles</option>
# <option value="20">20 miles</option>
# <option value="30">30 miles</option>
# <option value="40">40 miles</option>
# <option value="50">50 miles</option>
# <option value="75">75 miles</option>
# <option selected="selected" value="100">100 miles</option>
# <option value="150">150 miles</option>
# <option value="200">200 miles</option>
# <option value="250">250 miles</option>
# <option value="500">500 miles</option>
# <option value="1000">Any distance</option>
# </select>
# </span>
# </div>
# <br/>
# <label for="venue-postcode">
#                                         Enter place or postcode:
#                                     </label>
# <div class="lta-form-field">
# <span class="lta-input-text">
# <input name="venue-postcode" rel="location" type="text"/>
# </span><a class="lta-refresh-btn lta-btn-alt" href="#"><span>Go</span> </a>
# </div>
# </div>
# </div>
# </div>
# <div class="by-club hide">
# <p>
#                                 To view competitions at your club only, search for the clubs below.</p>
# <label for="find-by-club">
#                                 Find your club</label>
# <div class="lta-form-field">
# <span class="lta-input-text">
# <input type="hidden"/>
# <input class="lta-autocomplete-venues-overlay" id="find-by-club" name="find-by-club" rel="club" type="text"/>
# </span><a class="by-club-refresh-btn lta-btn-alt" href="#"><span>Go</span> </a>
# </div>
# </div>
# <div class="lta-location-message">
# <em>You can only choose one type of location filter at any one time. If you apply more
#                                 than one the most recent filter applied will be used.</em>
# </div>
# </div>
# </div>
# <div class="lta-filter-go-btn">
# <a class="lta-btn-alt"><span>Go</span> </a>
# </div>
# </div>
# </div>
# </div>
# <div class="lta-invalid-location-overlay lta-form lta-form-alternate">
# <div class="lta-invalid-location-overlay-content">
# <div class="lta-invalid-location-overlay-body clear">
# <p>
#                     Sorry, we do not recognise this location.
#                 </p>
# <p>
#                     Please try again. <a class="lta-btn-alt" href="#"><span>OK</span> </a>
# </p>
# </div>
# </div>
# </div>
# <script src="/javascript/jquery.address.js" type="text/javascript"></script>
# <script src="/javascript/jquery.blockUI.js" type="text/javascript"></script>
# <script src="/javascript/smartpaginator.js" type="text/javascript"></script>
# <script src="/javascript/competitionSearch.js?v=1.0" type="text/javascript"></script>
# <script src="/javascript/popupusersurvey.js" type="text/javascript"></script>
# <!-- noindex -->
# <!-- START OF Google Analytics CODE -->
# <!-- END OF Google Analytics CODE -->
# <!-- /noindex -->
# <script type="text/javascript">
#     (function(i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date(); a = s.createElement(o),
#   m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-9407701-4', 'auto');
#     ga('send', 'pageview');
#
# </script>
# </body>
# <!--googleon: all-->
# </html>

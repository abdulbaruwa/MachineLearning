# %% [markdown]
# ### A Spam Classifier Attempt

# %%
import os

# Data prep
train_dir = '/home/datadrive/PythonDev/datasets/Spam/raw/easy_ham'
spam_train_dir = '/home/datadrive/PythonDev/datasets/Spam/raw/spam'
processed_dir = '/home/datadrive/PythonDev/datasets/Spam/Processed/'

emails = [os.path.join(train_dir, f)for f in os.listdir(train_dir)]
#spam_emails = [os.path.join(train_dir, f)for f in os.listdir(spam_train_dir)]
#emails += spam_emails

# %%
import re
def html_cleaner(text):
    cleaned = re.sub(r"(?s)[\n]?", "", text)
    # Next remove the remaining tags:
    cleaned = re.sub(r"(?s)<.*?>", " ", cleaned)
    # Finally deal with whitespace
    cleaned = re.sub(r" ", " ", cleaned)
    cleaned = re.sub(r"^$", "", cleaned)
    cleaned = re.sub("''|,", "", cleaned)
    cleaned = re.sub(r"  ", " ", cleaned)
    return cleaned

# %%
def get_all_words_from_emails(emails):
    all_words = []
    cnt = 0;
    for mail in emails:
        # cnt += 1
        # print(mail)
        raw_data = ''
        try:
            raw_data = open(mail, 'r').read()
            
        except UnicodeDecodeError as ex:
            print(ex)
            print(mail)
        cleaned = html_cleaner(raw_data)
        all_words += cleaned.split()   
    return all_words

# %%
# Clean up to get 
from collections import Counter

all_words = get_all_words_from_emails(emails)
dictionary = Counter(all_words)

# remove non-words 
to_remove = [item for item in dictionary.keys()]
for item in to_remove:
    if item.isalpha() == False:
        del dictionary[item]
    elif len(item) == 1:
        del dictionary[item]
dictionary = dictionary.most_common()
# Out:
# 'utf-8' codec can't decode byte 0xa0 in position 1169: invalid start byte
# /home/datadrive/PythonDev/datasets/Spam/raw/easy_ham/2393.9ba2bbda6af818512632047ddd5aea4a
# 'utf-8' codec can't decode byte 0xe4 in position 4522: invalid continuation byte
# /home/datadrive/PythonDev/datasets/Spam/raw/easy_ham/1121.51f7e5e557bde451a6b36e527211ed04
# 'utf-8' codec can't decode byte 0xe9 in position 12619: invalid continuation byte
# /home/datadrive/PythonDev/datasets/Spam/raw/easy_ham/0326.703aa5be82f6586d348723b732176418
# 'utf-8' codec can't decode byte 0x92 in position 2459: invalid start byte
# /home/datadrive/PythonDev/datasets/Spam/raw/easy_ham/00492.3ffb38f175e41790b1f05096dbe339d8
# 'utf-8' codec can't decode byte 0xa9 in position 3287: invalid start byte
# /home/datadrive/PythonDev/datasets/Spam/raw/easy_ham/01337.e515b1d01d6d98606d994b1c8901904c
# 'utf-8' codec can't decode byte 0xa0 in position 1249: invalid start byte
# ...

# %%
raw_data = open(mail, 'r').read()
cleaned = html_cleaner(raw_data)
with open(re.sub('raw/','Processed/', i), 'w') as f:
    f.write(cleaned)

# %%
def read_subject(file):
    all_words = []
    subject = ''
    with open(mail) as m:
        for i, line in enumerate(m):
            if subject == '':
                if line.rfind('Subject:',0) > -1:
                    subject = line[9:]
                    pass
        return subject

# %%
# Out:
# 'Re: [ILUG] connecting at 1200bps in RH7.3 (help!)\n'

# %%
# Process files
for i in emails:
    raw_data = open(i, 'r').read()
    cleaned = html_cleaner(raw_data)
    with open(re.sub('raw/','Processed/', i), 'w') as f:
        f.write(cleaned)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-a5ffa9d7fa69> in <module>()
#       1 # Process files
#       2 for i in emails:
# ----> 3     raw_data = open(i, 'r').read()
#       4     cleaned = html_cleaner(raw_data)
#       5     with open(re.sub('raw/','Processed/', i), 'w') as f:
#
# /home/dayo/.conda/envs/py3/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 1169: invalid start byte

# %%
all_words = []
subject = ''
with open(mail) as m:
    for i, line in enumerate(m):
        if subject == '':
            if line.rfind('Subject:',0) > -1:
                subject = line[9:]
        if i > :
            all_words.append(line)
            print(line)
# Out:
# List-Subscribe: <https://example.sourceforge.net/lists/listinfo/razor-users>,
#
#     <mailto:razor-users-request@lists.sourceforge.net?subject=subscribe>
#
# List-Id: <razor-users.example.sourceforge.net>
#
# List-Unsubscribe: <https://example.sourceforge.net/lists/listinfo/razor-users>,
#
#     <mailto:razor-users-request@lists.sourceforge.net?subject=unsubscribe>
#
# List-Archive: <http://sourceforge.net/mailarchives/forum.php?forum=razor-users>
#
# X-Original-Date: Wed, 18 Sep 2002 23:21:40 -0600
#
# Date: Wed, 18 Sep 2002 23:21:40 -0600
#
# X-Spam-Status: No, hits=-11.8 required=5.0
#
# 	tests=AWL,IN_REP_TO,KNOWN_MAILING_LIST,PGP_SIGNATURE_2,
#
# 	      QUOTED_EMAIL_TEXT,REFERENCES,REPLY_WITH_QUOTES,USER_AGENT,
#
# 	      USER_AGENT_MUTT
#
# 	version=2.50-cvs
#
# X-Spam-Level:
#
#
#
#
#
# --huq684BweRXVnRxX
#
# Content-Type: text/plain; charset=us-ascii
#
# Content-Disposition: inline
#
#
#
# Gary Funck <gary@intrepid.com> [2002-09-18 13:57:00 -0700]:
#
# ...

# %%
wrds = [item[0] for item in dictionary]

# %%
tst = wrds[0:10]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(analyzer='word', tokenizer=None, preprocessor=None, stop_words=None)

# %%
wrds_transformed = vectorizer.fit_transform(wrds)

# %%
wrds_array = wrds_transformed.toarray()

# %%
len(wrds_array[0])
# Out:
# 24828
